# %%
"""
Ada 2 metode deteksi outlier yang paling sering:
  1. statistik dengan IQR (Inter Quartile Range)
  2. Visualisasi data (biasanya dengan bloxplot atau scatter)

atau pakai model ML yg nggak tidak sensitif terhadap data outlier
"""

# %%
"""
Penganganan Data Outlier:
  - Hapus Outlier
  - Capping: Ubah menjadi Q3 atau Q1
  - Imputasi: Ganti dengan nilai seperti Median, Mean, atau Modus dan lainnya
"""
