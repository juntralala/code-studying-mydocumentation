# %%
import numpy as np

np.full(10, 20)
# Out:
# array([20, 20, 20, 20, 20, 20, 20, 20, 20, 20])

# %%
arr = np.array([[
        [10, 20],
        [10, 20]
    ],[
        [5, 10],
        [8, 12],
    ]])

arr.flatten()
# Out:
# array([10, 20, 10, 20,  5, 10,  8, 12])
