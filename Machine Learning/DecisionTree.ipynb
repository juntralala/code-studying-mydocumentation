# %%
"""
Hyper Paramter utama:
    criterion
    max_depth
    max_features
    splitter                default:best ;opsi=best, random
    min_samples_split
    min_samples_nodes
    min_leaf_nodes
    min_impurity_decrease
"""

# %%
from sklearn.tree import DecisionTreeClassifier
import pandas as pd

# %%
# berat, tinggi
x = [
    [ 55, 160],
    [ 53, 175],
    [ 48, 152],
    [ 90, 182],
    [ 65, 168],
    [ 70, 178],
    [ 45, 155],
    [ 80, 185],
    [ 60, 163],
    [ 58, 170]
]
# Jenis Kelamin
y = ["P", "L", "P", "L", "L", "L", "P", "L", "P", "P"]

model = DecisionTreeClassifier()
model.fit(x, y)

model.predict([[50, 170]])
# Out:
# array(['L'], dtype='<U1')
