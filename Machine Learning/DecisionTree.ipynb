# %%
"""
Hyper Paramter utama:
    criterion
    max_depth
    max_features
    min_samples_split
    min_samples_nodes
    min_leaf_nodes
    min_impurity_decrease
"""

# %%
from sklearn.tree import DecisionTreeClassifier
