# %%
"""
Paramter Utama SVM:
    Kernel            -> default=rbf ;opsi=linear,poly,rbf,sigmoid,precomputed atau callable
    Gamma             -> default=scale ;opsi=scale,auto,float
    Regularization (c) -> default=1.0 ;opsi=float
    Degree
"""
